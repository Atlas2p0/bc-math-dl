# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch.optim as optim

# %% [markdown]
# ## Lab Objectives Overview:
#
# In this lab I intend to observe the effects of Batch Normalization on the simple CNN I have built the previous days.
#
# For this lab I will be testing my knowledge and understanding after reading the Batch Norm foundational paper -> Ioffe, S., & Szegedy, C. (2015, June). Batch normalization: Accelerating deep network training by reducing internal covariate shift.
#
# Methodology and Assumptions:
#
# * I am removing Data Augmentation because I think it harms this model more than it serves it as the model is really simple and augmenting the data and complicating the features would add noise to my experiments
#
# * In this lab i am using typical architectures with the only difference being batch norm to control the experiment more to see the net improvement Batch Norm brings to a simple model like this

# %%
torch.manual_seed(42)
BATCH_SIZE= 32

transform_aug= transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    # transforms.RandomHorizontalFlip(p=0.5),
    # transforms.ColorJitter(
    # brightness=0.5,  # Randomly adjust brightness by a factor between [max(0, 1-0.5), 1+0.5] = [0.5, 1.5]
    # contrast=(0.8, 1.2),  # Randomly adjust contrast by a factor between 0.8 and 1.2
    # saturation=0.3,  # Randomly adjust saturation by a factor between [max(0, 1-0.3), 1+0.3] = [0.7, 1.3]
    # hue=(-0.1, 0.1))  # Randomly adjust hue by a factor between -0.1 and 0.1
])

train_dataset= torchvision.datasets.CIFAR10(root= './data', train= True, download= True, transform= transform_aug)
test_dataset= torchvision.datasets.CIFAR10(root= './data', train= False, download= True, transform= transform_aug)

train_loader= DataLoader(dataset= train_dataset, batch_size= BATCH_SIZE, shuffle= True)
test_loader= DataLoader(dataset= test_dataset, batch_size= BATCH_SIZE, shuffle= False)

class_names= train_dataset.classes
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 36.8MB/s]

# %%
def display_images(images, labels, class_names, indices, n_rows= 3, n_cols= 3, figsize= (15,12)):
    fig, axes= plt.subplots(n_rows, n_cols, figsize= figsize)

    axes= axes.flatten()
    for i, idx in enumerate(indices):
        image= images[idx].permute(1,2,0).numpy()
        label= labels[idx].item()

        axes[i].imshow(image.squeeze())
        axes[i].axis(False)
        axes[i].set_title(f"Image Class: {class_names[label]}")
    plt.tight_layout()
    plt.show()
images, labels= next(iter(train_loader))
indices= [1,6, 16, 9, 7, 25, 29, 2, 4]
display_images(images, labels, class_names, indices)
images.shape
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9638278..2.4559333].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.4182549..1.9147888].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0219827..2.5781386].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.3199205..2.4415667].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.2018826..2.3202388].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0642517..1.8297836].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.4290657..2.7537313].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.83616227..1.5831139].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5775534..2.3411214].
# torch.Size([32, 3, 32, 32])

# %%
class SmallCNN(nn.Module):
    def __init__(self):
        super().__init__()
        # Conv Block 1
        self.conv1= nn.Conv2d(in_channels= 3,
                              out_channels= 32,
                              kernel_size= 3,
                              stride= 1,
                              padding= 0) # Input Shape: (batch_size, 3, 32, 32) Output Shape: (batch_size, 32, 30, 30)
        self.relu1= nn.LeakyReLU(0.1)
        self.pool1= nn.MaxPool2d(kernel_size= 2) # Input Shape: (batch_size, 32, 30, 30) Output Shape: (batch_size, 32, 15, 15)
        self.dropout1= nn.Dropout(p= 0.2)

        # Conv Block 2
        self.conv2= nn.Conv2d(in_channels= 32,
                              out_channels= 64,
                              kernel_size= 3,
                              stride= 1,
                              padding= 0) # Input Shape: (batch_size, 32, 15, 15) Out: (batch_size, 64, 13, 13)
        self.relu2= nn.LeakyReLU(0.1)
        self.pool2= nn.MaxPool2d(kernel_size= 2) # Input Shape: (batch_size, 64, 13, 13) Out: (batch_size, 64, 6, 6)
        self.dropout2= nn.Dropout(p= 0.3)

        self.flatten= nn.Flatten()

        self.fc1= nn.Linear(64 * 6 * 6, 256)
        self.relu3= nn.LeakyReLU(0.1)
        self.dropout3= nn.Dropout(p= 0.4)
        self.output= nn.Linear(256, 10)

        # Initialize weights
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

        self.activation_std_history= [] # List of Dicts: [{'fc1': std, ....}, ...]
        self.gradient_std_history= [] # Same for gradients


    def forward(self, x):
        # Feature Learning
        features= self.dropout1(self.pool1(self.relu1(self.conv1(x))))
        features= self.dropout2(self.pool2(self.relu2(self.conv2(features))))
        # Classification
        features= self.flatten(features)
        features= self.dropout3(self.relu3(self.fc1(features)))

        output= self.output(features)

        return output

    def register_std_hooks(self):
    # Clear any existing hooks to avoid duplicates (if called multiple times)
        self._hooks = []  # List to store hook handles for potential removal
        self.activation_stds = {}
        self.gradient_stds = {}

        # Define the types of modules to track
        types_to_track = (nn.Conv2d, nn.LeakyReLU, nn.Linear)

        # Iterate over all modules in the model
        for name, module in self.named_modules():
            if isinstance(module, types_to_track):
                # Forward hook: capture output activations
                def forward_hook(module, input, output, name=name):
                    if output.numel() > 1:  # Avoid scalar tensors
                        std = torch.std(output.detach().view(-1)).item()
                        self.activation_stds[name] = std
                    else:
                        self.activation_stds[name] = 0.0

                # Backward hook: capture output gradients
                def backward_hook(module, grad_input, grad_output, name=name):
                    if grad_output[0] is not None and grad_output[0].numel() > 1:
                        std = torch.std(grad_output[0].detach().view(-1)).item()
                        self.gradient_stds[name] = std
                    else:
                        self.gradient_stds[name] = 0.0

                # Register hooks and store handles
                forward_handle = module.register_forward_hook(forward_hook)
                backward_handle = module.register_full_backward_hook(backward_hook)
                self._hooks.extend([forward_handle, backward_handle])  # Store handles for later removal if needed

    # Append current pass stds to history and clear temp trackers (unchanged, it's good)
    def log_std_to_history(self):
        self.activation_std_history.append(self.activation_stds.copy())
        self.gradient_std_history.append(self.gradient_stds.copy())
        self.activation_stds = {}
        self.gradient_stds = {}

# %%
class BNSmallCNN(nn.Module):
    def __init__(self):
        super().__init__()
        # Conv Block 1
        self.conv1= nn.Conv2d(in_channels= 3,
                              out_channels= 32,
                              kernel_size= 3,
                              stride= 1,
                              padding= 0) # Input Shape: (batch_size, 3, 32, 32) Output Shape: (batch_size, 32, 30, 30)
        self.bn1= nn.BatchNorm2d(num_features= 32)
        self.relu1= nn.LeakyReLU(0.1)
        self.pool1= nn.MaxPool2d(kernel_size= 2) # Input Shape: (batch_size, 32, 30, 30) Output Shape: (batch_size, 32, 15, 15)
        self.dropout1= nn.Dropout(p= 0.2)

        # Conv Block 2
        self.conv2= nn.Conv2d(in_channels= 32,
                              out_channels= 64,
                              kernel_size= 3,
                              stride= 1,
                              padding= 0) # Input Shape: (batch_size, 32, 15, 15) Out: (batch_size, 64, 13, 13)
        self.bn2= nn.BatchNorm2d(num_features= 64)
        self.relu2= nn.LeakyReLU(0.1)
        self.pool2= nn.MaxPool2d(kernel_size= 2) # Input Shape: (batch_size, 64, 13, 13) Out: (batch_size, 64, 6, 6)
        self.dropout2= nn.Dropout(p= 0.3)

        self.flatten= nn.Flatten()

        self.fc1= nn.Linear(64 * 6 * 6, 256)
        self.relu3= nn.LeakyReLU(0.1)
        self.dropout3= nn.Dropout(p= 0.4)
        self.output= nn.Linear(256, 10)

        # Initialize weights
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

        self.activation_std_history= [] # List of Dicts: [{'fc1': std, ....}, ...]
        self.gradient_std_history= [] # Same for gradients


    def forward(self, x):
        # Feature Learning
        features= self.dropout1(self.pool1(self.relu1(self.bn1(self.conv1(x)))))
        features= self.dropout2(self.pool2(self.relu2(self.bn2(self.conv2(features)))))
        # Classification
        features= self.flatten(features)
        features= self.dropout3(self.relu3(self.fc1(features)))

        output= self.output(features)

        return output

    def register_std_hooks(self):
    # Clear any existing hooks to avoid duplicates (if called multiple times)
        self._hooks = []  # List to store hook handles for potential removal
        self.activation_stds = {}
        self.gradient_stds = {}

        # Define the types of modules to track
        types_to_track = (nn.Conv2d, nn.LeakyReLU, nn.Linear)

        # Iterate over all modules in the model
        for name, module in self.named_modules():
            if isinstance(module, types_to_track):
                # Forward hook: capture output activations
                def forward_hook(module, input, output, name=name):
                    if output.numel() > 1:  # Avoid scalar tensors
                        std = torch.std(output.detach().view(-1)).item()
                        self.activation_stds[name] = std
                    else:
                        self.activation_stds[name] = 0.0

                # Backward hook: capture output gradients
                def backward_hook(module, grad_input, grad_output, name=name):
                    if grad_output[0] is not None and grad_output[0].numel() > 1:
                        std = torch.std(grad_output[0].detach().view(-1)).item()
                        self.gradient_stds[name] = std
                    else:
                        self.gradient_stds[name] = 0.0

                # Register hooks and store handles
                forward_handle = module.register_forward_hook(forward_hook)
                backward_handle = module.register_full_backward_hook(backward_hook)
                self._hooks.extend([forward_handle, backward_handle])  # Store handles for later removal if needed

    # Append current pass stds to history and clear temp trackers (unchanged, it's good)
    def log_std_to_history(self):
        self.activation_std_history.append(self.activation_stds.copy())
        self.gradient_std_history.append(self.gradient_stds.copy())
        self.activation_stds = {}
        self.gradient_stds = {}

# %%
def train_eval_model(model,
                     train_loader,
                     test_loader,
                     optimizer,
                     num_epochs,
                     device,
                     loss_fn,
                     scheduler= None):
    # Logging and Early Stopping Vars
    train_loss_history= []
    val_loss_history= []
    train_acc_history= []
    val_acc_history= []
    activation_std_history= []
    gradient_std_history= []
    patience= 3
    best_val_accuracy= 0.0
    epochs_with_no_improvement= 0
    min_delta= 0.1
    model.register_std_hooks()

    for epoch in range(num_epochs):
        model.train()
        running_train_loss= 0.0
        train_correct= 0
        train_total= 0

        for images, labels in train_loader:
            # Move data to device
            images, labels= images.to(device), labels.to(device)

            # Forward Pass + Loss Calc
            preds= model(images)
            loss= loss_fn(preds, labels)

            # Backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Accumulate loss
            running_train_loss+= loss.item()

            # Calculate Training Accuracy
            _, predicted= torch.max(preds.data, 1)
            train_total+= labels.size(0)
            train_correct+= (predicted == labels).sum().item()

        # Log activation/gradient std
        model.log_std_to_history()
        activation_std_history.append(model.activation_std_history[-1])
        gradient_std_history.append(model.gradient_std_history[-1])

        model.eval()
        running_val_loss= 0.0
        val_correct= 0
        val_total= 0

        with torch.no_grad():
            for images, labels in test_loader:
                images, labels= images.to(device), labels.to(device)
                preds= model(images)
                loss= loss_fn(preds, labels)

                running_val_loss+= loss.item()

                _, predicted= torch.max(preds.data, 1)
                val_total+= labels.size(0)
                val_correct+= (predicted == labels).sum().item()

        running_val_loss/= len(test_loader)
        running_train_loss/= len(train_loader)

        train_acc= (train_correct / train_total) * 100
        val_acc= (val_correct / val_total) * 100

        if val_acc >= best_val_accuracy + min_delta:
            best_val_accuracy= val_acc
            epochs_with_no_improvement= 0
        else:
            epochs_with_no_improvement+= 1

        # Log history and print
        train_loss_history.append(running_train_loss)
        val_loss_history.append(running_val_loss)
        train_acc_history.append(train_acc)
        val_acc_history.append(val_acc)

        print(f"Epoch {epoch + 1}/{num_epochs} ")
        print("-" * 10)
        print(f"Train Loss: {running_train_loss:.4f}")
        print(f"Train Accuracy: {train_acc:.2f}%")
        print(f"Val Loss: {running_val_loss:.4f}")
        print(f"Val Accuracy: {val_acc:.2f}%")
        print("Activation STDs:", model.activation_std_history[-1])
        print("Gradient STDs:", model.gradient_std_history[-1])
        print("-" * 50)

        if epochs_with_no_improvement >= patience:
            print(f"Early Stopping Triggered at Epoch {epoch + 1}. No improvement after {patience} Epochs")
            break

        if scheduler:
            scheduler.step(metrics= val_loss_history[-1])
    epochs= [epoch for epoch in range(1, len(train_loss_history) + 1)]
    return {
    "epochs": epochs,
    "train_loss_history": train_loss_history,
    "val_loss_history": val_loss_history,
    "train_acc_history": train_acc_history,
    "val_acc_history": val_acc_history,
    "activation_std_history": activation_std_history,
    "gradient_std_history": gradient_std_history
    }

# %%
torch.manual_seed(42)
LEARNING_RATE_ADAM= 0.001
LEARNING_RATE_SGD= 0.01
NUM_EPOCHS= 30
device= torch.device('cuda' if torch.cuda.is_available() else 'cpu')
loss_fn= nn.CrossEntropyLoss()

control_cnn_adam_model= SmallCNN()
control_cnn_adam_optimizer= optim.Adam(control_cnn_adam_model.parameters(), LEARNING_RATE_ADAM)
control_cnn_adam_scheduler= optim.lr_scheduler.ReduceLROnPlateau(control_cnn_adam_optimizer, mode= 'min', factor= 0.1, patience= 3)

bn_cnn_adam_model= BNSmallCNN()
bn_cnn_adam_optimizer= optim.Adam(bn_cnn_adam_model.parameters(), LEARNING_RATE_ADAM)
bn_cnn_adam_scheduler= optim.lr_scheduler.ReduceLROnPlateau(bn_cnn_adam_optimizer, mode= 'min', factor= 0.1, patience= 3)

control_sgd_model= SmallCNN()
control_sgd_optimizer= optim.SGD(control_sgd_model.parameters(), LEARNING_RATE_SGD, momentum= 0.9)
control_sgd_scheduler= optim.lr_scheduler.ReduceLROnPlateau(control_sgd_optimizer, mode= 'min', factor= 0.1, patience= 3)

bn_cnn_sgd_model= BNSmallCNN()
bn_cnn_sgd_optimizer= optim.SGD(bn_cnn_sgd_model.parameters(), LEARNING_RATE_SGD, momentum= 0.9)
bn_cnn_sgd_scheduler= optim.lr_scheduler.ReduceLROnPlateau(bn_cnn_sgd_optimizer, mode= 'min', factor= 0.1, patience= 3)

print(f"Control CNN W/Adam Training Start...")
print(f"-"*80)
control_cnn_adam_model.to(device)
control_cnn_adam_model_metrics= train_eval_model(model= control_cnn_adam_model,
                                train_loader= train_loader,
                                test_loader= test_loader,
                                optimizer= control_cnn_adam_optimizer,
                                num_epochs= NUM_EPOCHS,
                                device= device,
                                loss_fn= loss_fn,
                                scheduler= control_cnn_adam_scheduler)
print(f"-"*80)
print(f"Batch Norm CNN W/Adam Training Start...")
print(f"-"*80)
bn_cnn_adam_model.to(device)
bn_cnn_adam_model_metrics= train_eval_model(model= bn_cnn_adam_model,
                                train_loader= train_loader,
                                test_loader= test_loader,
                                optimizer= bn_cnn_adam_optimizer,
                                num_epochs= NUM_EPOCHS,
                                device= device,
                                loss_fn= loss_fn,
                                scheduler= bn_cnn_adam_scheduler)
print(f"-"*80)
print(f"Control CNN W/SGD Training Start...")
print(f"-"*80)
control_sgd_model.to(device)
control_sgd_model_metrics= train_eval_model(model= control_sgd_model,
                                train_loader= train_loader,
                                test_loader= test_loader,
                                optimizer= control_sgd_optimizer,
                                num_epochs= NUM_EPOCHS,
                                device= device,
                                loss_fn= loss_fn,
                                scheduler= control_sgd_scheduler)
print(f"-"*80)
print(f"Batchn Norm CNN W/SGD Training Start...")
print(f"-"*80)
bn_cnn_sgd_model.to(device)
bn_cnn_sgd_model_metrics= train_eval_model(model= bn_cnn_sgd_model,
                                train_loader= train_loader,
                                test_loader= test_loader,
                                optimizer= bn_cnn_sgd_optimizer,
                                num_epochs= NUM_EPOCHS,
                                device= device,
                                loss_fn= loss_fn,
                                scheduler= bn_cnn_sgd_scheduler)
print(f"-"*80)
# Out:
# Control CNN W/Adam Training Start...
# --------------------------------------------------------------------------------
# sys:1: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# Epoch 1/30
# ----------
# Train Loss: 1.5092
# Train Accuracy: 47.27%
# Val Loss: 1.4654
# Val Accuracy: 51.36%
# Activation STDs: {'conv1': 0.811917781829834, 'relu1': 0.49458229541778564, 'conv2': 1.4322528839111328, 'relu2': 0.30780407786369324, 'fc1': 1.9063242673873901, 'relu3': 0.7630888223648071, 'output': 3.290616035461426}
# Gradient STDs: {'output': 0.014451623894274235, 'relu3': 0.004250855650752783, 'fc1': 0.001801320700906217, 'relu2': 0.0009108420345000923, 'conv2': 0.000447630271082744, 'relu1': 0.0004915347089990973, 'conv1': 0.0003861205477733165}
# --------------------------------------------------
# Epoch 2/30
# ----------
# Train Loss: 1.1457
# Train Accuracy: 59.78%
# Val Loss: 1.1747
# Val Accuracy: 60.11%
# Activation STDs: {'conv1': 0.6768242716789246, 'relu1': 0.3799537420272827, 'conv2': 1.4242477416992188, 'relu2': 0.28516918420791626, 'fc1': 2.044482469558716, 'relu3': 0.7204506993293762, 'output': 2.5728063583374023}
# Gradient STDs: {'output': 0.01541654672473669, 'relu3': 0.00395520543679595, 'fc1': 0.0015266077825799584, 'relu2': 0.0009320226963609457, 'conv2': 0.0004690578789450228, 'relu1': 0.0005498183891177177, 'conv1': 0.00039523496525362134}
# --------------------------------------------------
# Epoch 3/30
# ----------
# Train Loss: 1.0204
# Train Accuracy: 64.20%
# Val Loss: 1.0213
# Val Accuracy: 65.91%
# Activation STDs: {'conv1': 0.6854031085968018, 'relu1': 0.3827431797981262, 'conv2': 1.4506114721298218, 'relu2': 0.3094424903392792, 'fc1': 3.232855796813965, 'relu3': 1.0602033138275146, 'output': 3.531785249710083}
# Gradient STDs: {'output': 0.01141679473221302, 'relu3': 0.0027564975898712873, 'fc1': 0.0011992651270702481, 'relu2': 0.0009735405328683555, 'conv2': 0.0004591986653394997, 'relu1': 0.0005751706194132566, 'conv1': 0.0004169124586042017}
# --------------------------------------------------
# Epoch 4/30
# ----------
# Train Loss: 0.9424
# Train Accuracy: 67.07%
# Val Loss: 0.8874
# Val Accuracy: 69.36%
# Activation STDs: {'conv1': 0.627935528755188, 'relu1': 0.33119428157806396, 'conv2': 1.5764106512069702, 'relu2': 0.3146476149559021, 'fc1': 3.364025115966797, 'relu3': 1.0464586019515991, 'output': 3.6583752632141113}
# Gradient STDs: {'output': 0.010569442994892597, 'relu3': 0.0023302773479372263, 'fc1': 0.0007835373398847878, 'relu2': 0.0006684706313535571, 'conv2': 0.0003469774092081934, 'relu1': 0.0004469958948902786, 'conv1': 0.00029541997355408967}
# --------------------------------------------------
# Epoch 5/30
# ----------
# Train Loss: 0.8839
# Train Accuracy: 69.28%
# Val Loss: 0.8378
# Val Accuracy: 70.70%
# Activation STDs: {'conv1': 0.6270511150360107, 'relu1': 0.3278660178184509, 'conv2': 1.7384591102600098, 'relu2': 0.3455546498298645, 'fc1': 4.241626262664795, 'relu3': 1.2465416193008423, 'output': 4.161217212677002}
# Gradient STDs: {'output': 0.0143267922103405, 'relu3': 0.0029808166436851025, 'fc1': 0.0011319015175104141, 'relu2': 0.00108626508153975, 'conv2': 0.0005886054714210331, 'relu1': 0.000825463910587132, 'conv1': 0.0005015248898416758}
# --------------------------------------------------
# Epoch 6/30
# ----------
# Train Loss: 0.8500
# Train Accuracy: 70.60%
# Val Loss: 0.8027
# Val Accuracy: 72.36%
# Activation STDs: {'conv1': 0.5711446404457092, 'relu1': 0.28163039684295654, 'conv2': 1.5234628915786743, 'relu2': 0.2858874201774597, 'fc1': 3.559865713119507, 'relu3': 1.1364859342575073, 'output': 4.008571624755859}
# Gradient STDs: {'output': 0.012848070822656155, 'relu3': 0.0026594705414026976, 'fc1': 0.0010403931373730302, 'relu2': 0.00108558579813689, 'conv2': 0.0005673285922966897, 'relu1': 0.0007989286677911878, 'conv1': 0.0005011340253986418}
# --------------------------------------------------
# Epoch 7/30
# ----------
# Train Loss: 0.8136
# Train Accuracy: 71.49%
# Val Loss: 0.7930
# Val Accuracy: 73.61%
# Activation STDs: {'conv1': 0.5328565239906311, 'relu1': 0.2509705126285553, 'conv2': 1.4056636095046997, 'relu2': 0.26980820298194885, 'fc1': 3.908233642578125, 'relu3': 1.3240950107574463, 'output': 4.464216232299805}
# Gradient STDs: {'output': 0.012243484146893024, 'relu3': 0.002768799429759383, 'fc1': 0.0012764385901391506, 'relu2': 0.0015060796868056059, 'conv2': 0.0007462238427251577, 'relu1': 0.0010931730503216386, 'conv1': 0.0006867446936666965}
# --------------------------------------------------
# Epoch 8/30
# ----------
# Train Loss: 0.7801
# Train Accuracy: 72.48%
# Val Loss: 0.7838
# Val Accuracy: 73.52%
# Activation STDs: {'conv1': 0.4799317419528961, 'relu1': 0.21940523386001587, 'conv2': 1.3063242435455322, 'relu2': 0.25439906120300293, 'fc1': 3.787842035293579, 'relu3': 1.2517105340957642, 'output': 3.676332950592041}
# Gradient STDs: {'output': 0.011070082895457745, 'relu3': 0.0024440630804747343, 'fc1': 0.0009511583484709263, 'relu2': 0.0012084359768778086, 'conv2': 0.0006770684849470854, 'relu1': 0.0010075242025777698, 'conv1': 0.0005411747260950506}
# --------------------------------------------------
# Epoch 9/30
# ----------
# Train Loss: 0.7587
# Train Accuracy: 73.42%
# Val Loss: 0.7934
# Val Accuracy: 73.54%
# Activation STDs: {'conv1': 0.533819317817688, 'relu1': 0.25099194049835205, 'conv2': 1.4942653179168701, 'relu2': 0.272708535194397, 'fc1': 4.087547779083252, 'relu3': 1.2903072834014893, 'output': 4.437740802764893}
# Gradient STDs: {'output': 0.013426531106233597, 'relu3': 0.0027294375468045473, 'fc1': 0.0011757266474887729, 'relu2': 0.0015693556051701307, 'conv2': 0.0007756205159239471, 'relu1': 0.0012359620304778218, 'conv1': 0.0007068479899317026}
# --------------------------------------------------
# Epoch 10/30
# ----------
# Train Loss: 0.7331
# Train Accuracy: 74.40%
# Val Loss: 0.7566
# Val Accuracy: 74.41%
# Activation STDs: {'conv1': 0.48655030131340027, 'relu1': 0.21717241406440735, 'conv2': 1.4113956689834595, 'relu2': 0.259818971157074, 'fc1': 4.028306007385254, 'relu3': 1.2751679420471191, 'output': 3.771343231201172}
# Gradient STDs: {'output': 0.013291428796947002, 'relu3': 0.0029300411697477102, 'fc1': 0.0012470668880268931, 'relu2': 0.0017276679864153266, 'conv2': 0.0009011822985485196, 'relu1': 0.001446720794774592, 'conv1': 0.0007573533221147954}
# --------------------------------------------------
# Epoch 11/30
# ----------
# Train Loss: 0.7201
# Train Accuracy: 74.97%
# Val Loss: 0.7706
# Val Accuracy: 73.84%
# Activation STDs: {'conv1': 0.48182687163352966, 'relu1': 0.21202346682548523, 'conv2': 1.419644832611084, 'relu2': 0.2505240738391876, 'fc1': 4.015395641326904, 'relu3': 1.2257254123687744, 'output': 3.4151716232299805}
# Gradient STDs: {'output': 0.01307548675686121, 'relu3': 0.002957601798698306, 'fc1': 0.0011284742504358292, 'relu2': 0.001610673381946981, 'conv2': 0.0008129368652589619, 'relu1': 0.0013098277850076556, 'conv1': 0.0007322599412873387}
# --------------------------------------------------
# Epoch 12/30
# ----------
# Train Loss: 0.6978
# Train Accuracy: 75.40%
# Val Loss: 0.7275
# Val Accuracy: 75.35%
# Activation STDs: {'conv1': 0.4752776324748993, 'relu1': 0.20181824266910553, 'conv2': 1.2899311780929565, 'relu2': 0.24760447442531586, 'fc1': 4.199212074279785, 'relu3': 1.3461554050445557, 'output': 3.724576234817505}
# Gradient STDs: {'output': 0.013195128180086613, 'relu3': 0.002838273998349905, 'fc1': 0.0010779242729768157, 'relu2': 0.001636960543692112, 'conv2': 0.0008955050725489855, 'relu1': 0.0014806928811594844, 'conv1': 0.0007607337320223451}
# --------------------------------------------------
# Epoch 13/30
# ----------
# Train Loss: 0.6890
# Train Accuracy: 75.79%
# Val Loss: 0.7111
# Val Accuracy: 75.86%
# Activation STDs: {'conv1': 0.44167834520339966, 'relu1': 0.18715576827526093, 'conv2': 1.2766798734664917, 'relu2': 0.23952381312847137, 'fc1': 4.344367980957031, 'relu3': 1.271363377571106, 'output': 4.045886039733887}
# Gradient STDs: {'output': 0.01161471288651228, 'relu3': 0.002737032249569893, 'fc1': 0.0010777486022561789, 'relu2': 0.0016983433160930872, 'conv2': 0.0009363378048874438, 'relu1': 0.0015915791736915708, 'conv1': 0.0007253909716382623}
# --------------------------------------------------
# Epoch 14/30
# ----------
# Train Loss: 0.6792
# Train Accuracy: 76.29%
# Val Loss: 0.7353
# Val Accuracy: 75.16%
# Activation STDs: {'conv1': 0.4780488610267639, 'relu1': 0.21480466425418854, 'conv2': 1.4483128786087036, 'relu2': 0.2633705139160156, 'fc1': 4.888657569885254, 'relu3': 1.6713895797729492, 'output': 4.569662570953369}
# Gradient STDs: {'output': 0.015174335800111294, 'relu3': 0.0033716412726789713, 'fc1': 0.0014890528982505202, 'relu2': 0.002475614892318845, 'conv2': 0.0010918043553829193, 'relu1': 0.0017838123021647334, 'conv1': 0.001000028452835977}
# --------------------------------------------------
# Epoch 15/30
# ----------
# Train Loss: 0.6643
# Train Accuracy: 76.71%
# Val Loss: 0.7317
# Val Accuracy: 75.76%
# Activation STDs: {'conv1': 0.4638226628303528, 'relu1': 0.20056018233299255, 'conv2': 1.5691688060760498, 'relu2': 0.26549118757247925, 'fc1': 5.044134140014648, 'relu3': 1.5824171304702759, 'output': 4.641274452209473}
# Gradient STDs: {'output': 0.013243697583675385, 'relu3': 0.002792918821796775, 'fc1': 0.0011289246613159776, 'relu2': 0.0018910078797489405, 'conv2': 0.0009312356123700738, 'relu1': 0.001531928894110024, 'conv1': 0.0007745246402919292}
# --------------------------------------------------
# Epoch 16/30
# ----------
# Train Loss: 0.6456
# Train Accuracy: 77.60%
# Val Loss: 0.7507
# Val Accuracy: 75.44%
# Activation STDs: {'conv1': 0.4526119530200958, 'relu1': 0.18708179891109467, 'conv2': 1.3127716779708862, 'relu2': 0.22713474929332733, 'fc1': 4.117084980010986, 'relu3': 1.3815919160842896, 'output': 3.8862271308898926}
# Gradient STDs: {'output': 0.01033604983240366, 'relu3': 0.0021204149816185236, 'fc1': 0.0009249197319149971, 'relu2': 0.0015740001108497381, 'conv2': 0.0008198719006031752, 'relu1': 0.001469562528654933, 'conv1': 0.0007313268142752349}
# --------------------------------------------------
# Early Stopping Triggered at Epoch 16. No improvement after 3 Epochs
# --------------------------------------------------------------------------------
# Batch Norm CNN W/Adam Training Start...
# --------------------------------------------------------------------------------
# Epoch 1/30
# ----------
# Train Loss: 1.6003
# Train Accuracy: 43.60%
# Val Loss: 1.1309
# Val Accuracy: 60.00%
# Activation STDs: {'conv1': 1.8498334884643555, 'relu1': 0.5895548462867737, 'conv2': 2.9499542713165283, 'relu2': 0.3814430832862854, 'fc1': 2.9380743503570557, 'relu3': 0.8202345967292786, 'output': 2.7899582386016846}
# Gradient STDs: {'output': 0.012946469709277153, 'relu3': 0.0029219097923487425, 'fc1': 0.0008628539508208632, 'relu2': 0.0004149039159528911, 'conv2': 0.0001222573482664302, 'relu1': 0.00015830667689442635, 'conv1': 0.00017414262401871383}
# --------------------------------------------------
# Epoch 2/30
# ----------
# Train Loss: 1.1733
# Train Accuracy: 58.65%
# Val Loss: 0.9675
# Val Accuracy: 65.91%
# Activation STDs: {'conv1': 1.4611774682998657, 'relu1': 0.5634711384773254, 'conv2': 3.2627766132354736, 'relu2': 0.25676506757736206, 'fc1': 2.389362096786499, 'relu3': 0.8333904147148132, 'output': 2.889695405960083}
# Gradient STDs: {'output': 0.014710272662341595, 'relu3': 0.0030742960516363382, 'fc1': 0.001362314447760582, 'relu2': 0.0008894394850358367, 'conv2': 0.00017099406977649778, 'relu1': 0.00024902011500671506, 'conv1': 0.0002844055707100779}
# --------------------------------------------------
# Epoch 3/30
# ----------
# Train Loss: 1.0278
# Train Accuracy: 64.01%
# Val Loss: 0.8735
# Val Accuracy: 69.94%
# Activation STDs: {'conv1': 1.5183018445968628, 'relu1': 0.5584750175476074, 'conv2': 3.5132880210876465, 'relu2': 0.2002396285533905, 'fc1': 2.121446132659912, 'relu3': 0.7611814737319946, 'output': 2.9566867351531982}
# Gradient STDs: {'output': 0.010458080098032951, 'relu3': 0.002572854980826378, 'fc1': 0.0011768812546506524, 'relu2': 0.0009782366687431931, 'conv2': 0.00014508579624816775, 'relu1': 0.00023200993018690497, 'conv1': 0.0002032492047874257}
# --------------------------------------------------
# Epoch 4/30
# ----------
# Train Loss: 0.9416
# Train Accuracy: 67.02%
# Val Loss: 0.8247
# Val Accuracy: 71.30%
# Activation STDs: {'conv1': 1.4755228757858276, 'relu1': 0.544284462928772, 'conv2': 3.7300660610198975, 'relu2': 0.1708514392375946, 'fc1': 2.1206400394439697, 'relu3': 0.729525625705719, 'output': 3.0468196868896484}
# Gradient STDs: {'output': 0.01495330035686493, 'relu3': 0.004068722017109394, 'fc1': 0.0018813718343153596, 'relu2': 0.00189594563562423, 'conv2': 0.00022405380150303245, 'relu1': 0.0003599565243348479, 'conv1': 0.0003573420690372586}
# --------------------------------------------------
# Epoch 5/30
# ----------
# Train Loss: 0.8806
# Train Accuracy: 68.98%
# Val Loss: 0.7955
# Val Accuracy: 72.27%
# Activation STDs: {'conv1': 1.484069585800171, 'relu1': 0.531945526599884, 'conv2': 3.950685977935791, 'relu2': 0.1629304736852646, 'fc1': 2.3373427391052246, 'relu3': 0.8680263161659241, 'output': 3.6087467670440674}
# Gradient STDs: {'output': 0.014200159348547459, 'relu3': 0.004083764273673296, 'fc1': 0.0019263203721493483, 'relu2': 0.002241704845800996, 'conv2': 0.0002209471131209284, 'relu1': 0.0003838040865957737, 'conv1': 0.00031855772249400616}
# --------------------------------------------------
# Epoch 6/30
# ----------
# Train Loss: 0.8328
# Train Accuracy: 70.88%
# Val Loss: 0.7734
# Val Accuracy: 73.25%
# Activation STDs: {'conv1': 1.5548900365829468, 'relu1': 0.5310013890266418, 'conv2': 3.9377832412719727, 'relu2': 0.15893897414207458, 'fc1': 2.2345545291900635, 'relu3': 0.7775397300720215, 'output': 3.2695565223693848}
# Gradient STDs: {'output': 0.012981107458472252, 'relu3': 0.004225060809403658, 'fc1': 0.0018606187077239156, 'relu2': 0.0022955858148634434, 'conv2': 0.00023410549329128116, 'relu1': 0.0004301367443986237, 'conv1': 0.0003836853720713407}
# --------------------------------------------------
# Epoch 7/30
# ----------
# Train Loss: 0.7961
# Train Accuracy: 71.96%
# Val Loss: 0.7417
# Val Accuracy: 74.56%
# Activation STDs: {'conv1': 1.4614264965057373, 'relu1': 0.5330455303192139, 'conv2': 4.318869590759277, 'relu2': 0.15239061415195465, 'fc1': 2.487377166748047, 'relu3': 0.7660732269287109, 'output': 3.3801703453063965}
# Gradient STDs: {'output': 0.012332390993833542, 'relu3': 0.003401698311790824, 'fc1': 0.0012546894140541553, 'relu2': 0.0016100631328299642, 'conv2': 0.00014891484170220792, 'relu1': 0.00028340809512883425, 'conv1': 0.00025737108080647886}
# --------------------------------------------------
# Epoch 8/30
# ----------
# Train Loss: 0.7665
# Train Accuracy: 73.21%
# Val Loss: 0.7374
# Val Accuracy: 74.74%
# Activation STDs: {'conv1': 1.2608109712600708, 'relu1': 0.5199563503265381, 'conv2': 4.38636589050293, 'relu2': 0.14769499003887177, 'fc1': 2.7235710620880127, 'relu3': 0.8676943182945251, 'output': 3.9916439056396484}
# Gradient STDs: {'output': 0.013656665571033955, 'relu3': 0.0043615614995360374, 'fc1': 0.0018604397773742676, 'relu2': 0.002607879228889942, 'conv2': 0.0002307231625309214, 'relu1': 0.00046231411397457123, 'conv1': 0.0004277386760804802}
# --------------------------------------------------
# Epoch 9/30
# ----------
# Train Loss: 0.7428
# Train Accuracy: 73.85%
# Val Loss: 0.7100
# Val Accuracy: 75.65%
# Activation STDs: {'conv1': 1.3132827281951904, 'relu1': 0.5243812203407288, 'conv2': 4.605172634124756, 'relu2': 0.1296500414609909, 'fc1': 2.4721627235412598, 'relu3': 0.8489587306976318, 'output': 4.12984037399292}
# Gradient STDs: {'output': 0.007914531044661999, 'relu3': 0.0023652941454201937, 'fc1': 0.001198158715851605, 'relu2': 0.0018304361728951335, 'conv2': 0.00014141021529212594, 'relu1': 0.0002822376845870167, 'conv1': 0.000265554990619421}
# --------------------------------------------------
# Epoch 10/30
# ----------
# Train Loss: 0.7229
# Train Accuracy: 74.56%
# Val Loss: 0.7320
# Val Accuracy: 75.34%
# Activation STDs: {'conv1': 1.2962433099746704, 'relu1': 0.5219681859016418, 'conv2': 4.709290027618408, 'relu2': 0.12866456806659698, 'fc1': 2.4160208702087402, 'relu3': 0.8334546089172363, 'output': 3.559539794921875}
# Gradient STDs: {'output': 0.009051681496202946, 'relu3': 0.003124342067167163, 'fc1': 0.0013451460981741548, 'relu2': 0.0020603288430720568, 'conv2': 0.00014686390932183713, 'relu1': 0.00031501398188993335, 'conv1': 0.00029778474709019065}
# --------------------------------------------------
# Epoch 11/30
# ----------
# Train Loss: 0.7045
# Train Accuracy: 75.40%
# Val Loss: 0.6985
# Val Accuracy: 75.83%
# Activation STDs: {'conv1': 1.3969597816467285, 'relu1': 0.5104905962944031, 'conv2': 4.8583197593688965, 'relu2': 0.13194693624973297, 'fc1': 2.4579296112060547, 'relu3': 0.7723268866539001, 'output': 3.376286268234253}
# Gradient STDs: {'output': 0.014284451492130756, 'relu3': 0.005094668362289667, 'fc1': 0.00215905555523932, 'relu2': 0.0033905962482094765, 'conv2': 0.00023360839986708015, 'relu1': 0.0005037396913394332, 'conv1': 0.00042018035310320556}
# --------------------------------------------------
# Epoch 12/30
# ----------
# Train Loss: 0.6870
# Train Accuracy: 76.00%
# Val Loss: 0.7463
# Val Accuracy: 75.29%
# Activation STDs: {'conv1': 1.3057451248168945, 'relu1': 0.5224462151527405, 'conv2': 5.2057294845581055, 'relu2': 0.12090583890676498, 'fc1': 2.4702377319335938, 'relu3': 0.8083249926567078, 'output': 3.5004172325134277}
# Gradient STDs: {'output': 0.011280634440481663, 'relu3': 0.003605256322771311, 'fc1': 0.0018421097192913294, 'relu2': 0.0030626871157437563, 'conv2': 0.00018130562966689467, 'relu1': 0.00040434885886497796, 'conv1': 0.0003639671194832772}
# --------------------------------------------------
# Epoch 13/30
# ----------
# Train Loss: 0.6678
# Train Accuracy: 76.66%
# Val Loss: 0.6943
# Val Accuracy: 76.30%
# Activation STDs: {'conv1': 1.35506272315979, 'relu1': 0.5042797923088074, 'conv2': 4.97921895980835, 'relu2': 0.13097475469112396, 'fc1': 2.5835134983062744, 'relu3': 0.867226779460907, 'output': 3.9387927055358887}
# Gradient STDs: {'output': 0.012981495819985867, 'relu3': 0.004637808073312044, 'fc1': 0.002014896832406521, 'relu2': 0.0034165591932833195, 'conv2': 0.00024633266730234027, 'relu1': 0.0005759001360274851, 'conv1': 0.0004950875882059336}
# --------------------------------------------------
# Epoch 14/30
# ----------
# Train Loss: 0.6571
# Train Accuracy: 76.77%
# Val Loss: 0.6998
# Val Accuracy: 76.61%
# Activation STDs: {'conv1': 1.4028226137161255, 'relu1': 0.5091637372970581, 'conv2': 4.897253036499023, 'relu2': 0.13296163082122803, 'fc1': 2.642627239227295, 'relu3': 0.8349045515060425, 'output': 3.66499924659729}
# Gradient STDs: {'output': 0.013741475529968739, 'relu3': 0.004853824153542519, 'fc1': 0.0019136181799694896, 'relu2': 0.0033659019973129034, 'conv2': 0.000234803490457125, 'relu1': 0.0005550479399971664, 'conv1': 0.00044982184772379696}
# --------------------------------------------------
# Epoch 15/30
# ----------
# Train Loss: 0.6463
# Train Accuracy: 77.22%
# Val Loss: 0.6743
# Val Accuracy: 77.02%
# Activation STDs: {'conv1': 1.417339563369751, 'relu1': 0.5093199610710144, 'conv2': 5.6939921379089355, 'relu2': 0.10856502503156662, 'fc1': 2.4467053413391113, 'relu3': 0.7656742334365845, 'output': 4.025619029998779}
# Gradient STDs: {'output': 0.012762993574142456, 'relu3': 0.004439993761479855, 'fc1': 0.002070534974336624, 'relu2': 0.00374784879386425, 'conv2': 0.0002012173063121736, 'relu1': 0.0004890389973297715, 'conv1': 0.0003653626481536776}
# --------------------------------------------------
# Epoch 16/30
# ----------
# Train Loss: 0.6330
# Train Accuracy: 77.86%
# Val Loss: 0.6730
# Val Accuracy: 77.23%
# Activation STDs: {'conv1': 1.3080180883407593, 'relu1': 0.5095950365066528, 'conv2': 5.35414457321167, 'relu2': 0.12215673178434372, 'fc1': 2.5917351245880127, 'relu3': 0.8940516114234924, 'output': 4.229008197784424}
# Gradient STDs: {'output': 0.013940611854195595, 'relu3': 0.005134830716997385, 'fc1': 0.0020478933583945036, 'relu2': 0.0037802455481141806, 'conv2': 0.00022856699069961905, 'relu1': 0.0005742644425481558, 'conv1': 0.0004696893156506121}
# --------------------------------------------------
# Epoch 17/30
# ----------
# Train Loss: 0.6183
# Train Accuracy: 78.29%
# Val Loss: 0.6836
# Val Accuracy: 77.18%
# Activation STDs: {'conv1': 1.3840868473052979, 'relu1': 0.5004121661186218, 'conv2': 5.743297100067139, 'relu2': 0.11931655555963516, 'fc1': 2.6825385093688965, 'relu3': 0.9352166056632996, 'output': 4.641659736633301}
# Gradient STDs: {'output': 0.011880530044436455, 'relu3': 0.00480730552226305, 'fc1': 0.0019816281273961067, 'relu2': 0.003751852549612522, 'conv2': 0.0002091171918436885, 'relu1': 0.0005390262813307345, 'conv1': 0.0004225467564538121}
# --------------------------------------------------
# Epoch 18/30
# ----------
# Train Loss: 0.6074
# Train Accuracy: 78.71%
# Val Loss: 0.6795
# Val Accuracy: 77.03%
# Activation STDs: {'conv1': 1.384084939956665, 'relu1': 0.5009853839874268, 'conv2': 5.45952033996582, 'relu2': 0.12072515487670898, 'fc1': 2.8052597045898438, 'relu3': 0.9145668745040894, 'output': 4.129230976104736}
# Gradient STDs: {'output': 0.011980638839304447, 'relu3': 0.004761017858982086, 'fc1': 0.001969507895410061, 'relu2': 0.003909294493496418, 'conv2': 0.00023872655583545566, 'relu1': 0.0006381115526892245, 'conv1': 0.0005106695462018251}
# --------------------------------------------------
# Epoch 19/30
# ----------
# Train Loss: 0.5992
# Train Accuracy: 78.75%
# Val Loss: 0.6674
# Val Accuracy: 77.28%
# Activation STDs: {'conv1': 1.5093191862106323, 'relu1': 0.4974602460861206, 'conv2': 5.723550319671631, 'relu2': 0.11329308152198792, 'fc1': 2.7156972885131836, 'relu3': 0.8723621368408203, 'output': 4.454949855804443}
# Gradient STDs: {'output': 0.006508945021778345, 'relu3': 0.002624767366796732, 'fc1': 0.0010316296247765422, 'relu2': 0.0019383671460673213, 'conv2': 0.00011346837709425017, 'relu1': 0.0003150254487991333, 'conv1': 0.00020207685884088278}
# --------------------------------------------------
# Early Stopping Triggered at Epoch 19. No improvement after 3 Epochs
# --------------------------------------------------------------------------------
# Control CNN W/SGD Training Start...
# --------------------------------------------------------------------------------
# Epoch 1/30
# ----------
# Train Loss: 1.5273
# Train Accuracy: 45.93%
# Val Loss: 1.1824
# Val Accuracy: 59.32%
# Activation STDs: {'conv1': 0.913188099861145, 'relu1': 0.4690759479999542, 'conv2': 1.7818174362182617, 'relu2': 0.37314876914024353, 'fc1': 1.5283212661743164, 'relu3': 0.5271642804145813, 'output': 2.262373208999634}
# Gradient STDs: {'output': 0.01865568943321705, 'relu3': 0.006247266661375761, 'fc1': 0.0026764844078570604, 'relu2': 0.0009451030637137592, 'conv2': 0.0005010130116716027, 'relu1': 0.0005809850990772247, 'conv1': 0.00036898517282679677}
# --------------------------------------------------
# Epoch 2/30
# ----------
# Train Loss: 1.2291
# Train Accuracy: 56.49%
# Val Loss: 1.1125
# Val Accuracy: 61.64%
# Activation STDs: {'conv1': 0.912682294845581, 'relu1': 0.41951367259025574, 'conv2': 1.889269232749939, 'relu2': 0.4029058516025543, 'fc1': 1.961154818534851, 'relu3': 0.532284140586853, 'output': 2.8150413036346436}
# Gradient STDs: {'output': 0.014524823054671288, 'relu3': 0.004561101086437702, 'fc1': 0.0015309419250115752, 'relu2': 0.0005794072058051825, 'conv2': 0.0003390068013686687, 'relu1': 0.0004097983182873577, 'conv1': 0.00022819907462690026}
# --------------------------------------------------
# Epoch 3/30
# ----------
# Train Loss: 1.1420
# Train Accuracy: 60.07%
# Val Loss: 1.0380
# Val Accuracy: 65.31%
# Activation STDs: {'conv1': 0.9120224714279175, 'relu1': 0.41128087043762207, 'conv2': 1.8196029663085938, 'relu2': 0.37104398012161255, 'fc1': 1.7720396518707275, 'relu3': 0.503467321395874, 'output': 2.3153927326202393}
# Gradient STDs: {'output': 0.01471118163317442, 'relu3': 0.004919857252389193, 'fc1': 0.0018169200047850609, 'relu2': 0.0007636285154148936, 'conv2': 0.000443295924924314, 'relu1': 0.0005730701377615333, 'conv1': 0.0002809435536619276}
# --------------------------------------------------
# Epoch 4/30
# ----------
# Train Loss: 1.0827
# Train Accuracy: 62.31%
# Val Loss: 1.0663
# Val Accuracy: 64.04%
# Activation STDs: {'conv1': 1.0167416334152222, 'relu1': 0.4568357467651367, 'conv2': 2.117004871368408, 'relu2': 0.40361106395721436, 'fc1': 2.2074344158172607, 'relu3': 0.6834174990653992, 'output': 3.172964572906494}
# Gradient STDs: {'output': 0.013555184938013554, 'relu3': 0.0049571203999221325, 'fc1': 0.0018653859151527286, 'relu2': 0.000830062897875905, 'conv2': 0.0004356633871793747, 'relu1': 0.0005762799410149455, 'conv1': 0.0003001303120981902}
# --------------------------------------------------
# Epoch 5/30
# ----------
# Train Loss: 1.0328
# Train Accuracy: 64.27%
# Val Loss: 1.0053
# Val Accuracy: 66.36%
# Activation STDs: {'conv1': 1.0216891765594482, 'relu1': 0.4343474209308624, 'conv2': 2.2165000438690186, 'relu2': 0.3917084336280823, 'fc1': 1.9817237854003906, 'relu3': 0.6225374341011047, 'output': 3.034480333328247}
# Gradient STDs: {'output': 0.012987911701202393, 'relu3': 0.004308879375457764, 'fc1': 0.0017321726772934198, 'relu2': 0.0008141924045048654, 'conv2': 0.0004304259200580418, 'relu1': 0.0005740108317695558, 'conv1': 0.0003032476524822414}
# --------------------------------------------------
# Epoch 6/30
# ----------
# Train Loss: 1.0079
# Train Accuracy: 65.16%
# Val Loss: 0.8638
# Val Accuracy: 70.91%
# Activation STDs: {'conv1': 1.1110725402832031, 'relu1': 0.48570090532302856, 'conv2': 2.4808661937713623, 'relu2': 0.45883721113204956, 'fc1': 2.631329298019409, 'relu3': 0.6305055618286133, 'output': 2.5855650901794434}
# Gradient STDs: {'output': 0.013229280710220337, 'relu3': 0.004521517548710108, 'fc1': 0.0014428398571908474, 'relu2': 0.0006788235041312873, 'conv2': 0.00038675247924402356, 'relu1': 0.0005166850169189274, 'conv1': 0.0002373028837610036}
# --------------------------------------------------
# Epoch 7/30
# ----------
# Train Loss: 0.9739
# Train Accuracy: 66.39%
# Val Loss: 0.8745
# Val Accuracy: 69.99%
# Activation STDs: {'conv1': 1.0913877487182617, 'relu1': 0.4874018728733063, 'conv2': 2.559711456298828, 'relu2': 0.461247980594635, 'fc1': 2.867173910140991, 'relu3': 0.7249027490615845, 'output': 3.2749106884002686}
# Gradient STDs: {'output': 0.016745494678616524, 'relu3': 0.005756937433034182, 'fc1': 0.002130921231582761, 'relu2': 0.001059335540048778, 'conv2': 0.0005649834638461471, 'relu1': 0.0007798984297551215, 'conv1': 0.0003840551944449544}
# --------------------------------------------------
# Epoch 8/30
# ----------
# Train Loss: 0.9527
# Train Accuracy: 67.14%
# Val Loss: 0.8989
# Val Accuracy: 70.25%
# Activation STDs: {'conv1': 0.9900823831558228, 'relu1': 0.40196487307548523, 'conv2': 2.2252726554870605, 'relu2': 0.3784794807434082, 'fc1': 2.204061985015869, 'relu3': 0.6421132683753967, 'output': 3.260805130004883}
# Gradient STDs: {'output': 0.012973449192941189, 'relu3': 0.0039433203637599945, 'fc1': 0.0018046492477878928, 'relu2': 0.0009497556020505726, 'conv2': 0.00041829075780697167, 'relu1': 0.0005792236770503223, 'conv1': 0.0003295945352874696}
# --------------------------------------------------
# Epoch 9/30
# ----------
# Train Loss: 0.9317
# Train Accuracy: 67.82%
# Val Loss: 0.8083
# Val Accuracy: 72.60%
# Activation STDs: {'conv1': 1.0078972578048706, 'relu1': 0.4021822214126587, 'conv2': 2.520850658416748, 'relu2': 0.4393353760242462, 'fc1': 2.69437575340271, 'relu3': 0.7204016447067261, 'output': 3.4945015907287598}
# Gradient STDs: {'output': 0.013830456882715225, 'relu3': 0.00442496407777071, 'fc1': 0.0015014616074040532, 'relu2': 0.000781940994784236, 'conv2': 0.00039735654718242586, 'relu1': 0.0005762917571701109, 'conv1': 0.0002958027471322566}
# --------------------------------------------------
# Epoch 10/30
# ----------
# Train Loss: 0.9209
# Train Accuracy: 68.16%
# Val Loss: 0.8697
# Val Accuracy: 70.83%
# Activation STDs: {'conv1': 1.0028934478759766, 'relu1': 0.3971385657787323, 'conv2': 2.426220178604126, 'relu2': 0.423983633518219, 'fc1': 2.563735246658325, 'relu3': 0.610763669013977, 'output': 3.131131887435913}
# Gradient STDs: {'output': 0.015063668601214886, 'relu3': 0.005435857456177473, 'fc1': 0.0021647168323397636, 'relu2': 0.0012117602163925767, 'conv2': 0.0007204687572084367, 'relu1': 0.0010611183242872357, 'conv1': 0.0004606293805409223}
# --------------------------------------------------
# Epoch 11/30
# ----------
# Train Loss: 0.9040
# Train Accuracy: 68.87%
# Val Loss: 0.8344
# Val Accuracy: 71.82%
# Activation STDs: {'conv1': 1.1192179918289185, 'relu1': 0.4870806634426117, 'conv2': 2.7431914806365967, 'relu2': 0.43386396765708923, 'fc1': 2.599073886871338, 'relu3': 0.6979234218597412, 'output': 3.2781968116760254}
# Gradient STDs: {'output': 0.013520966283977032, 'relu3': 0.0050451261922717094, 'fc1': 0.001776232267729938, 'relu2': 0.0009637493058107793, 'conv2': 0.0004812802071683109, 'relu1': 0.0007272899383679032, 'conv1': 0.00035827429383061826}
# --------------------------------------------------
# Epoch 12/30
# ----------
# Train Loss: 0.8850
# Train Accuracy: 69.43%
# Val Loss: 0.8457
# Val Accuracy: 71.94%
# Activation STDs: {'conv1': 0.9913748502731323, 'relu1': 0.38125497102737427, 'conv2': 2.53651762008667, 'relu2': 0.3884294331073761, 'fc1': 2.2896244525909424, 'relu3': 0.7471022009849548, 'output': 4.00723123550415}
# Gradient STDs: {'output': 0.01170735340565443, 'relu3': 0.004166936501860619, 'fc1': 0.0017809872515499592, 'relu2': 0.0010228956816717982, 'conv2': 0.0005857552168890834, 'relu1': 0.0008651064126752317, 'conv1': 0.0003353914071340114}
# --------------------------------------------------
# Early Stopping Triggered at Epoch 12. No improvement after 3 Epochs
# --------------------------------------------------------------------------------
# Batchn Norm CNN W/SGD Training Start...
# --------------------------------------------------------------------------------
# Epoch 1/30
# ----------
# Train Loss: 1.5664
# Train Accuracy: 44.01%
# Val Loss: 1.1800
# Val Accuracy: 58.33%
# Activation STDs: {'conv1': 1.931786298751831, 'relu1': 0.5959988832473755, 'conv2': 2.5437393188476562, 'relu2': 0.2264939844608307, 'fc1': 1.1321488618850708, 'relu3': 0.38632991909980774, 'output': 2.294430732727051}
# Gradient STDs: {'output': 0.014810456894338131, 'relu3': 0.005231211893260479, 'fc1': 0.0027013702783733606, 'relu2': 0.00097767380066216, 'conv2': 0.00019774393877014518, 'relu1': 0.0002227651420980692, 'conv1': 0.00014262956392485648}
# --------------------------------------------------
# Epoch 2/30
# ----------
# Train Loss: 1.2105
# Train Accuracy: 56.95%
# Val Loss: 1.0310
# Val Accuracy: 63.33%
# Activation STDs: {'conv1': 1.5920356512069702, 'relu1': 0.582746148109436, 'conv2': 2.868340492248535, 'relu2': 0.18557724356651306, 'fc1': 1.0044833421707153, 'relu3': 0.36638107895851135, 'output': 2.89951229095459}
# Gradient STDs: {'output': 0.01382596604526043, 'relu3': 0.005967834498733282, 'fc1': 0.0029816378373652697, 'relu2': 0.0012696501798927784, 'conv2': 0.00020562618738040328, 'relu1': 0.00025396564160473645, 'conv1': 0.00017323243082500994}
# --------------------------------------------------
# Epoch 3/30
# ----------
# Train Loss: 1.0854
# Train Accuracy: 61.66%
# Val Loss: 0.9213
# Val Accuracy: 67.49%
# Activation STDs: {'conv1': 1.7280969619750977, 'relu1': 0.5749151110649109, 'conv2': 3.0748190879821777, 'relu2': 0.18010841310024261, 'fc1': 1.0137280225753784, 'relu3': 0.36326614022254944, 'output': 2.9952352046966553}
# Gradient STDs: {'output': 0.011900527402758598, 'relu3': 0.006243341602385044, 'fc1': 0.002926730550825596, 'relu2': 0.0013003665953874588, 'conv2': 0.00018738742801360786, 'relu1': 0.000244321912759915, 'conv1': 0.00014462332183029503}
# --------------------------------------------------
# Epoch 4/30
# ----------
# Train Loss: 1.0071
# Train Accuracy: 64.61%
# Val Loss: 0.9205
# Val Accuracy: 67.81%
# Activation STDs: {'conv1': 1.5349774360656738, 'relu1': 0.5747363567352295, 'conv2': 3.3061461448669434, 'relu2': 0.17596013844013214, 'fc1': 1.0275812149047852, 'relu3': 0.3604721128940582, 'output': 2.491490125656128}
# Gradient STDs: {'output': 0.014107965864241123, 'relu3': 0.007034392561763525, 'fc1': 0.0033291715662926435, 'relu2': 0.0015675949398428202, 'conv2': 0.00020486649009399116, 'relu1': 0.0002916863013524562, 'conv1': 0.00018648963305167854}
# --------------------------------------------------
# Epoch 5/30
# ----------
# Train Loss: 0.9498
# Train Accuracy: 66.69%
# Val Loss: 0.8417
# Val Accuracy: 70.39%
# Activation STDs: {'conv1': 1.8432307243347168, 'relu1': 0.5707374215126038, 'conv2': 3.278709650039673, 'relu2': 0.1913294792175293, 'fc1': 1.1311801671981812, 'relu3': 0.3545902669429779, 'output': 2.9978976249694824}
# Gradient STDs: {'output': 0.011336496099829674, 'relu3': 0.006252956110984087, 'fc1': 0.002406085841357708, 'relu2': 0.0011411919258534908, 'conv2': 0.00015624206571374089, 'relu1': 0.00021778076188638806, 'conv1': 0.0001109481236198917}
# --------------------------------------------------
# Epoch 6/30
# ----------
# Train Loss: 0.9048
# Train Accuracy: 68.43%
# Val Loss: 0.8396
# Val Accuracy: 70.65%
# Activation STDs: {'conv1': 1.8286211490631104, 'relu1': 0.5699825882911682, 'conv2': 3.4798407554626465, 'relu2': 0.18083375692367554, 'fc1': 1.315138816833496, 'relu3': 0.40624716877937317, 'output': 3.3653762340545654}
# Gradient STDs: {'output': 0.015091056935489178, 'relu3': 0.0085641173645854, 'fc1': 0.004282521083950996, 'relu2': 0.0022125064861029387, 'conv2': 0.00026048594736494124, 'relu1': 0.00039321446092799306, 'conv1': 0.00020342328934930265}
# --------------------------------------------------
# Epoch 7/30
# ----------
# Train Loss: 0.8639
# Train Accuracy: 69.65%
# Val Loss: 0.7950
# Val Accuracy: 72.30%
# Activation STDs: {'conv1': 2.0812199115753174, 'relu1': 0.5690471529960632, 'conv2': 3.682542324066162, 'relu2': 0.18818038702011108, 'fc1': 1.2347207069396973, 'relu3': 0.3955194056034088, 'output': 3.333869457244873}
# Gradient STDs: {'output': 0.013278537429869175, 'relu3': 0.007319729309529066, 'fc1': 0.0033021029084920883, 'relu2': 0.001776974182575941, 'conv2': 0.00021422130521386862, 'relu1': 0.00033282808726653457, 'conv1': 0.00014973701036069542}
# --------------------------------------------------
# Epoch 8/30
# ----------
# Train Loss: 0.8394
# Train Accuracy: 70.56%
# Val Loss: 0.7882
# Val Accuracy: 72.71%
# Activation STDs: {'conv1': 1.88934326171875, 'relu1': 0.587678849697113, 'conv2': 3.8660061359405518, 'relu2': 0.1779928356409073, 'fc1': 1.2603473663330078, 'relu3': 0.383486807346344, 'output': 3.360626459121704}
# Gradient STDs: {'output': 0.012568190693855286, 'relu3': 0.007482320070266724, 'fc1': 0.0033011266496032476, 'relu2': 0.0018101761816069484, 'conv2': 0.0001971831952687353, 'relu1': 0.0003119476023130119, 'conv1': 0.00015122018521651626}
# --------------------------------------------------
# Epoch 9/30
# ----------
# Train Loss: 0.8173
# Train Accuracy: 71.33%
# Val Loss: 0.7638
# Val Accuracy: 73.62%
# Activation STDs: {'conv1': 1.9181642532348633, 'relu1': 0.581167459487915, 'conv2': 3.8828186988830566, 'relu2': 0.18947122991085052, 'fc1': 1.2412627935409546, 'relu3': 0.3703773319721222, 'output': 3.029787302017212}
# Gradient STDs: {'output': 0.013949958607554436, 'relu3': 0.009578638710081577, 'fc1': 0.00424597505480051, 'relu2': 0.0024755755439400673, 'conv2': 0.00027832589694298804, 'relu1': 0.00044796772999688983, 'conv1': 0.00021496371482498944}
# --------------------------------------------------
# Epoch 10/30
# ----------
# Train Loss: 0.7908
# Train Accuracy: 72.41%
# Val Loss: 0.7378
# Val Accuracy: 74.34%
# Activation STDs: {'conv1': 2.028074026107788, 'relu1': 0.5769784450531006, 'conv2': 3.9696764945983887, 'relu2': 0.19531358778476715, 'fc1': 1.4003709554672241, 'relu3': 0.4216916561126709, 'output': 3.6243536472320557}
# Gradient STDs: {'output': 0.00814854633063078, 'relu3': 0.004748781211674213, 'fc1': 0.002354430267587304, 'relu2': 0.0013817610451951623, 'conv2': 0.00015421269927173853, 'relu1': 0.00026689699734561145, 'conv1': 0.00012645394599530846}
# --------------------------------------------------
# Epoch 11/30
# ----------
# Train Loss: 0.7685
# Train Accuracy: 73.16%
# Val Loss: 0.7712
# Val Accuracy: 73.57%
# Activation STDs: {'conv1': 1.948869228363037, 'relu1': 0.5780792236328125, 'conv2': 4.0526123046875, 'relu2': 0.19338886439800262, 'fc1': 1.384833574295044, 'relu3': 0.40879857540130615, 'output': 3.2905876636505127}
# Gradient STDs: {'output': 0.01234852708876133, 'relu3': 0.007013077847659588, 'fc1': 0.0028783108573406935, 'relu2': 0.0015896520344540477, 'conv2': 0.00018222579092253, 'relu1': 0.00031907600350677967, 'conv1': 0.0001493575400672853}
# --------------------------------------------------
# Epoch 12/30
# ----------
# Train Loss: 0.7478
# Train Accuracy: 73.83%
# Val Loss: 0.7464
# Val Accuracy: 74.52%
# Activation STDs: {'conv1': 2.0478670597076416, 'relu1': 0.581151008605957, 'conv2': 4.368890285491943, 'relu2': 0.1750892847776413, 'fc1': 1.2855408191680908, 'relu3': 0.39111432433128357, 'output': 3.2442448139190674}
# Gradient STDs: {'output': 0.01564023271203041, 'relu3': 0.009430219419300556, 'fc1': 0.0042628394439816475, 'relu2': 0.0025651659816503525, 'conv2': 0.0002609584480524063, 'relu1': 0.0004501646035350859, 'conv1': 0.0001985740673262626}
# --------------------------------------------------
# Epoch 13/30
# ----------
# Train Loss: 0.7359
# Train Accuracy: 74.21%
# Val Loss: 0.7228
# Val Accuracy: 75.10%
# Activation STDs: {'conv1': 1.9723962545394897, 'relu1': 0.5839171409606934, 'conv2': 4.488342761993408, 'relu2': 0.17978163063526154, 'fc1': 1.3538528680801392, 'relu3': 0.4474790692329407, 'output': 4.018832683563232}
# Gradient STDs: {'output': 0.00935632735490799, 'relu3': 0.005765581037849188, 'fc1': 0.0022582379169762135, 'relu2': 0.0013792585814371705, 'conv2': 0.00013456407759804279, 'relu1': 0.00023628826602362096, 'conv1': 9.668216807767749e-05}
# --------------------------------------------------
# Epoch 14/30
# ----------
# Train Loss: 0.7225
# Train Accuracy: 74.75%
# Val Loss: 0.7753
# Val Accuracy: 74.05%
# Activation STDs: {'conv1': 2.2432854175567627, 'relu1': 0.5968652963638306, 'conv2': 4.525467872619629, 'relu2': 0.18273064494132996, 'fc1': 1.4278236627578735, 'relu3': 0.4754810333251953, 'output': 4.1254563331604}
# Gradient STDs: {'output': 0.008814431726932526, 'relu3': 0.005221715662628412, 'fc1': 0.002466968260705471, 'relu2': 0.0014897865476086736, 'conv2': 0.00015036229160614312, 'relu1': 0.00027648010291159153, 'conv1': 0.00010476362513145432}
# --------------------------------------------------
# Epoch 15/30
# ----------
# Train Loss: 0.7052
# Train Accuracy: 75.41%
# Val Loss: 0.7042
# Val Accuracy: 75.37%
# Activation STDs: {'conv1': 2.090062379837036, 'relu1': 0.5970343947410583, 'conv2': 4.712362289428711, 'relu2': 0.19393159449100494, 'fc1': 1.4902828931808472, 'relu3': 0.45028191804885864, 'output': 3.617013692855835}
# Gradient STDs: {'output': 0.01008918322622776, 'relu3': 0.007329246960580349, 'fc1': 0.002816205145791173, 'relu2': 0.0016893480205908418, 'conv2': 0.00017250418022740632, 'relu1': 0.0003275309572927654, 'conv1': 0.00013909657718613744}
# --------------------------------------------------
# Epoch 16/30
# ----------
# Train Loss: 0.6959
# Train Accuracy: 75.54%
# Val Loss: 0.7292
# Val Accuracy: 75.20%
# Activation STDs: {'conv1': 1.957987666130066, 'relu1': 0.5931888222694397, 'conv2': 4.786756992340088, 'relu2': 0.18291932344436646, 'fc1': 1.4644336700439453, 'relu3': 0.4836459457874298, 'output': 3.7805917263031006}
# Gradient STDs: {'output': 0.011957253329455853, 'relu3': 0.007787278387695551, 'fc1': 0.003025152487680316, 'relu2': 0.0018264317186549306, 'conv2': 0.0001711341756163165, 'relu1': 0.0003121251065749675, 'conv1': 0.00014311248378362507}
# --------------------------------------------------
# Epoch 17/30
# ----------
# Train Loss: 0.6812
# Train Accuracy: 76.01%
# Val Loss: 0.7274
# Val Accuracy: 75.26%
# Activation STDs: {'conv1': 2.4753715991973877, 'relu1': 0.6009719967842102, 'conv2': 4.6735944747924805, 'relu2': 0.18598078191280365, 'fc1': 1.4524136781692505, 'relu3': 0.4806860685348511, 'output': 4.195226192474365}
# Gradient STDs: {'output': 0.011662733741104603, 'relu3': 0.007162091322243214, 'fc1': 0.0033756045158952475, 'relu2': 0.002151971450075507, 'conv2': 0.0002095337986247614, 'relu1': 0.00039015646325424314, 'conv1': 0.0001384790666634217}
# --------------------------------------------------
# Epoch 18/30
# ----------
# Train Loss: 0.6748
# Train Accuracy: 76.34%
# Val Loss: 0.7250
# Val Accuracy: 75.42%
# Activation STDs: {'conv1': 2.2082128524780273, 'relu1': 0.6161956787109375, 'conv2': 4.990060329437256, 'relu2': 0.18849098682403564, 'fc1': 1.659189224243164, 'relu3': 0.4927327036857605, 'output': 4.129610061645508}
# Gradient STDs: {'output': 0.011191596277058125, 'relu3': 0.007234870921820402, 'fc1': 0.003455816302448511, 'relu2': 0.002384891966357827, 'conv2': 0.00019894895376637578, 'relu1': 0.0003817690594587475, 'conv1': 0.00017347389075439423}
# --------------------------------------------------
# Early Stopping Triggered at Epoch 18. No improvement after 3 Epochs
# --------------------------------------------------------------------------------

# %%
# Create figure with 3 rows and 2 columns
fig, axes = plt.subplots(4, 2, figsize=(25, 20))

# Data to plot (model metrics)
models_data = [
    (control_cnn_adam_model_metrics, f"Control CNN W/ Adam LR: {LEARNING_RATE_ADAM}"),
    (bn_cnn_sgd_model_metrics, f"Batch Norm CNN W/ Adam LR: {LEARNING_RATE_ADAM}"),
    (control_sgd_model_metrics, f"Control CNN W/ SGD LR: {LEARNING_RATE_SGD}"),
    (bn_cnn_sgd_model_metrics, f"Batch Norm CNN W/ SGD LR: {LEARNING_RATE_SGD}")

]

# Precompute global min and max for loss and accuracy
all_losses = []
all_accuracies = []
for metrics, _ in models_data:
    all_losses.extend(metrics["train_loss_history"])
    all_losses.extend(metrics["val_loss_history"])
    all_accuracies.extend(metrics["train_acc_history"])
    all_accuracies.extend(metrics["val_acc_history"])

# Add 5% padding to the ranges
loss_padding = (max(all_losses) - min(all_losses)) * 0.05
acc_padding = (max(all_accuracies) - min(all_accuracies)) * 0.05

# Set consistent y-axis limits for all plots
for i in range(4):
    # Left column (loss plots)
    axes[i, 0].set_ylim(min(all_losses) - loss_padding, max(all_losses) + loss_padding)

    # Right column (accuracy plots)
    axes[i, 1].set_ylim(min(all_accuracies) - acc_padding, max(all_accuracies) + acc_padding)

# Create plots for each model
for i, (metrics, title) in enumerate(models_data):
    # Left plot (loss)
    ax_left = axes[i, 0]
    ax_left.set_title(f"{title} - Loss Per Epoch")
    ax_left.grid(True, alpha=0.5)
    ax_left.set_xlabel("Epoch")
    ax_left.set_ylabel("Loss")
    p1 = ax_left.plot(metrics["epochs"], metrics["train_loss_history"], label='Train Loss')
    p2 = ax_left.plot(metrics["epochs"], metrics["val_loss_history"], label='Validation Loss')
    ax_left.legend()

    # Right plot (accuracy)
    ax_right = axes[i, 1]
    ax_right.set_title(f"{title} - Accuracy Per Epoch")
    ax_right.grid(True, alpha=0.5)
    ax_right.set_xlabel("Epoch")
    ax_right.set_ylabel("Accuracy (%)")
    p3 = ax_right.plot(metrics["epochs"], metrics["train_acc_history"], label='Train Accuracy')
    p4 = ax_right.plot(metrics["epochs"], metrics["val_acc_history"], label='Validation Accuracy')
    ax_right.legend()

# Add overall title and adjust layout
fig.suptitle(f"The Effect of Regularization on Training",
             fontsize=16, y=1.0)
fig.tight_layout(h_pad=2.0, w_pad=1.5)

plt.show()
